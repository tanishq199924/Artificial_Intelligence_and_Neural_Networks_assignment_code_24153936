# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from sklearn.metrics import confusion_matrix
import seaborn as sns
import time

# -------------------------------
# 1. LOAD AND PREPROCESS DATA
# -------------------------------
def load_and_preprocess():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

    # Normalise
    x_train = x_train / 255.0
    x_test = x_test / 255.0

    return x_train, y_train, x_test, y_test


# -------------------------------
# 2. VISUALISE SAMPLE DIGITS
# -------------------------------
def show_sample_digits(images, labels):
    plt.figure(figsize=(10,4))
    for i in range(10):
        plt.subplot(2,5,i+1)
        plt.imshow(images[i], cmap='gray')
        plt.title(f"Label: {labels[i]}")
        plt.axis('off')
    plt.show()


# -------------------------------
# 3. BUILD DEEP NEURAL NETWORK
# -------------------------------
def build_model(activation):
    model = models.Sequential([
        layers.Flatten(input_shape=(28,28)),

        layers.Dense(128, activation=activation),
        layers.Dense(128, activation=activation),
        layers.Dense(64, activation=activation),
        layers.Dense(64, activation=activation),
        layers.Dense(32, activation=activation),
        layers.Dense(32, activation=activation),

        layers.Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model


# -------------------------------
# 4. TRAIN AND EVALUATE MODEL
# -------------------------------
def train_model(model, x_train, y_train, x_test, y_test):
    start_time = time.time()

    history = model.fit(
        x_train, y_train,
        epochs=15,
        batch_size=32,
        validation_data=(x_test, y_test),
        verbose=1
    )

    training_time = time.time() - start_time
    test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)

    return history, training_time, test_accuracy


# -------------------------------
# 5. PLOT ACCURACY & LOSS
# -------------------------------
def plot_history(history, title):
    plt.figure(figsize=(12,4))

    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(f"{title} Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend(['Train','Validation'])

    plt.subplot(1,2,2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(f"{title} Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(['Train','Validation'])

    plt.show()


# -------------------------------
# 6. CONFUSION MATRIX
# -------------------------------
def show_confusion_matrix(model, x_test, y_test, title):
    predictions = np.argmax(model.predict(x_test), axis=1)
    cm = confusion_matrix(y_test, predictions)

    plt.figure(figsize=(7,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(title)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()


# ===============================
# MAIN EXECUTION
# ===============================
x_train, y_train, x_test, y_test = load_and_preprocess()
show_sample_digits(x_train, y_train)

# Sigmoid Model
model_sigmoid = build_model('sigmoid')
hist_sig, time_sig, acc_sig = train_model(model_sigmoid, x_train, y_train, x_test, y_test)
plot_history(hist_sig, "Sigmoid")
show_confusion_matrix(model_sigmoid, x_test, y_test, "Sigmoid Confusion Matrix")

# Tanh Model
model_tanh = build_model('tanh')
hist_tanh, time_tanh, acc_tanh = train_model(model_tanh, x_train, y_train, x_test, y_test)
plot_history(hist_tanh, "Tanh")
show_confusion_matrix(model_tanh, x_test, y_test, "Tanh Confusion Matrix")

# ReLU Model (Extension)
model_relu = build_model('relu')
hist_relu, time_relu, acc_relu = train_model(model_relu, x_train, y_train, x_test, y_test)
plot_history(hist_relu, "ReLU")
show_confusion_matrix(model_relu, x_test, y_test, "ReLU Confusion Matrix")

print("Final Test Accuracies:")
print(f"Sigmoid: {acc_sig:.4f}")
print(f"Tanh:    {acc_tanh:.4f}")
print(f"ReLU:    {acc_relu:.4f}")
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.2417 - loss: 1.8942 - val_accuracy: 0.5951 - val_loss: 1.0739
# Epoch 2/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.6633 - loss: 0.8861 - val_accuracy: 0.9240 - val_loss: 0.3290
# Epoch 3/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9335 - loss: 0.2723 - val_accuracy: 0.9449 - val_loss: 0.2138
# Epoch 4/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9542 - loss: 0.1744 - val_accuracy: 0.9571 - val_loss: 0.1675
# Epoch 5/15
# ...
